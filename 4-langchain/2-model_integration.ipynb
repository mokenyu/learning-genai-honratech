# %% [markdown]
# ### Model Integration with OpenAI, Google Gemini and Groq

# %% [markdown]
# #### init

# %%
import os
from dotenv import load_dotenv # 
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("google_genai:gemini-3.5-flash")

response = model.invoke("Hello, how are you?")

response.content
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [{'type': 'text',
#   'text': "Hello! I'm doing great, thank you for asking. How are you doing today? How can I help you?",
#   'extras': {'signature': '...'}}]

# %% [markdown]
# ##### OpenAI with dedicated langchain package

# %%
from langchain_openai import ChatOpenAI

# model = ChatOpenAI(
#     model="gemini-2.5-flash",        # Passes target name to LiteLLM
#     openai_api_key="sk-dummy-key",   # Dummy key to satisfy OpenAI SDK
#     openai_api_base="http://localhost:4000"  # LiteLLM proxy endpoint
# )

model = ChatOpenAI(model="gpt-4o")
response = model.invoke("Hello")
response.content

# %% [markdown]
# #### Gemini

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Hey wassup")
response.content
# Out:
# "Hey there! Not much, just here and ready to help. What's up with you, or what can I do for you today?"

# %% [markdown]
# ##### Gemini using dedicated langchain lib

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash")
response = llm.invoke("Hello")
response.content
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [{'type': 'text',
#   'text': 'Hello! How can I help you today?',
#   'extras': {'signature': '...'}}]

# %% [markdown]
# #### GROQ

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("groq:qwen/qwen3.6-27b")
response = model.invoke("Hello zere")
response.content

# %% [markdown]
# ##### Langchain dedicated Groq Library

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.3-70b-versatile")
response = model.invoke("Hello")
response.content

# %% [markdown]
# ### Streaming and Batch

# %% [markdown]
# #### Streaming

# %%
stream_text = model.stream("Write a 200 word paragraph about why dogs cannot speak")

for chunk in stream_text:
    print(chunk.text, end="", flush=True)
# Out:
# Dogs cannot speak human language due to a combination of physical and neurological limitations. Anatomically, their vocal tracts are not designed for the complex manipulation of sound required for speech. While humans possess a highly flexible larynx, tongue, and lips capable of shaping precise vowels and consonants, a dog’s vocal apparatus is structured primarily for producing simpler, survival-based sounds like barks, whines, and growls. Furthermore, their brains lack the specialized neural architecture, such as Broca’s and Wernicke’s areas, which allow humans to process, organize, and produce complex syntactic language. Evolutionary biology also plays a key role; dogs simply never needed verbal speech to survive. Instead, they developed a highly sophisticated system of non-verbal communication. They rely heavily on olfactory cues, body posture, tail positioning, and subtle facial expressions to convey their emotions and intentions to both other dogs and humans. While a dog can understand and interpret dozens of human words and commands, they do not possess the biological tools—neither the cognitive hardware nor the physical vocal software—to speak them back. Consequently, their silence is not a lack of intelligence, but rather a beautiful reflection of their unique evolutionary path, proving that love needs no words to be felt.

# %%
for chunk in model.stream("why do parrots wear colorful feathers?"):
    print(chunk.text, end="", flush=True)

# %% [markdown]
# #### Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs as the processing can be done in parallel.

# %%
responses = model.batch([
    "Hello, how are you?",
    "What is quantum entanglement?",
    "What is the capital of France?"
    ],
    config = {
        "max_concurrency": 5 # the max concurrency tells the moodel how many concuurrent requests it can handle at once e.g. if 10 requests are sent, it will process 5 at a time.
    }
)

for response in responses:
    print(response.content)

# %% [markdown]
# ### LLM Generation Hyperparameters & Configuration
#
# Understanding and tuning parameters like `temperature`, `top_p`, `top_k`, `max_tokens` / `max_output_tokens`, and `stop_sequences` is essential for controlling model behavior, determinism, cost, and latency.

# %% [markdown]
# #### 1. Temperature
#
# `temperature` controls the randomness of token predictions during sampling:
# * **Low (0.0 - 0.2)**: Focused, deterministic, reproducible. Ideal for classification, code generation, RAG, and math.
# * **Moderate (0.5 - 0.7)**: Balanced coherence and natural variety. Standard default for general Q&A and conversational agents.
# * **High (0.8 - 1.5+)**: Creative, diverse, and unconventional. Ideal for brainstorming, storytelling, and divergent ideation.

# %%
# Demonstrating Temperature with ChatGoogleGenerativeAI
from langchain_google_genai import ChatGoogleGenerativeAI

prompt = "Invent a name and a one-sentence slogan for a futuristic quantum coffee shop."

# Deterministic (temperature=0.0)
llm_deterministic = ChatGoogleGenerativeAI(model="gemini-3.5-flash", temperature=0.0)
print("--- Temperature = 0.0 (Deterministic) ---")
print(llm_deterministic.invoke(prompt).content)

# Highly Creative (temperature=1.2)
llm_creative = ChatGoogleGenerativeAI(model="gemini-3.5-flash", temperature=1.2)
print("\n--- Temperature = 1.2 (Creative) ---")
print(llm_creative.invoke(prompt).content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# --- Temperature = 0.0 (Deterministic) ---
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [{'type': 'text', 'text': '**Name:** Superposition Coffee\n\n**Slogan:** "You are both tired and awake until the first sip collapses the wave function."', 'extras': {'signature': '...'}}]
#
# --- Temperature = 1.2 (Creative) ---
# [{'type': 'text', 'text': '**Name:** Superposition Brews\n\n**Slogan:** *Simultaneously hot, iced, and perfect in every reality until your first sip.*', 'extras': {'signature': '...'}}]

# %% [markdown]
# #### 2. Top-P (Nucleus Sampling) and Top-K
#
# * **`top_p` (Nucleus Sampling)**: Dynamically selects tokens from the smallest candidate pool whose cumulative probability mass meets or exceeds `top_p` (e.g., `0.9` keeps the top 90% of probability mass). It cuts off the long tail of unlikely tokens while keeping sampling adaptive.
# * **`top_k`**: Restricts the token candidate pool strictly to the `K` highest probability tokens at each generation step (e.g., `top_k=40`), discarding all others regardless of probability distribution.

# %%
# Demonstrating Top-P (Nucleus Sampling) & Top-K candidate pooling
llm_sampling = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash",
    temperature=0.8,
    top_p=0.85,
    top_k=40
)

response_sampling = llm_sampling.invoke("Suggest 3 innovative robotics features for agriculture.")
print("--- Top-P (0.85) & Top-K (40) Generation ---")
print(response_sampling.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# --- Top-P (0.85) & Top-K (40) Generation ---
# [{'type': 'text', 'text': 'Here are 3 innovative robotics features designed to address the next generation of challenges in agriculture, focusing on sustainability, labor shortages, and precision.\n\n---\n\n### 1. Olfactory-Guided Soft Grippers (for Delicate Harvesting)\nWhile computer vision is great for finding fruit, it cannot determine if a peach is soft and sweet, nor can rigid metal claws harvest it without bruising. This feature combines **soft robotics** with **artificial olfaction (e-nose technology)**.\n\n*   **How it works:** The robot’s gripper is made of food-safe, fluid-filled silicone actuators that mimic the gentle, adaptive grip of a human hand. Embedded at the fingertips are chemical sensors that "smell" the Volatile Organic Compounds (VOCs) emitted by the fruit. \n*   **The Innovation:** The robot doesn\'t just look at color; it sniffs the fruit to determine exact ripeness. If the VOC profile indicates peak ripeness, the soft gripper inflates to the exact pressure needed to twist the fruit off the stem without causing cellular damage or bruising.\n*   **Impact:** Enables the automated harvesting of highly delicate crops (like strawberries, peaches, and tomatoes) that previously required manual labor, reducing food waste from bruising during harvest.\n\n---\n\n### 2. Sub-Canopy Acoustic Soil Tomography (for Micro-Soil Health)\nMost agricultural robots and drones analyze crops from above. This feature uses a team of small, low-profile ground robots (swarms) operating *beneath* the crop canopy to map the soil in 3D using sound waves.\n\n*   **How it works:** As the small robots traverse the fields, they emit low-frequency acoustic pulses into the ground. Companion robots nearby receive these signals. By analyzing how the sound waves travel through the earth, the system constructs a real-time, 3D map of the subsurface.\n*   **The Innovation:** This acts as an "ultrasound" for the field. It detects soil compaction layers, moisture levels, and root depth without disturbing the soil. \n*   **Impact:** Farmers can apply water and fertilizer only where the roots actually need it, preventing runoff. It also identifies "hardpan" (compacted soil layers) so farmers can perform targeted aeration rather than tilling the entire field, preserving soil microbiomes and saving fuel.\n\n---\n\n### 3. Micro-Targeted Directed Energy & Bio-Injection (for Chemical-Free Weeding)\nCurrent weeding robots use lasers to burn weeds, which can be energy-intensive and fire-hazardous in dry conditions. This feature combines high-speed precision weeding with instant biological soil enhancement.\n\n*   **How it works:** Using ultra-high-speed edge AI, the robot distinguishes weeds from crops at a millimeter scale. Instead of a continuous laser, it uses a **high-frequency micro-plasma burst** to vaporize the weed’s growth cell (meristem) in milliseconds. Simultaneously, a micro-needle injects a localized dose of beneficial microbes or bio-fungicides directly into the soil next to the crop\'s root.\n*   **The Innovation:** It pairs destructive weed control with constructive crop support in a single, split-second action. It uses a fraction of the energy of standard lasers and zero synthetic herbicides.\n*   **Impact:** Eliminates the need for chemical herbicides, prevents herbicide resistance in weeds, and actively boosts the crop’s immune system and growth at the individual plant level.', 'extras': {'signature': '...'}}]

# %% [markdown]
# #### 3. Max Tokens (`max_tokens` / `max_output_tokens`) & Stop Sequences (`stop_sequences`)
#
# * **`max_output_tokens`**: Caps the maximum number of completion tokens generated. Protects cost budgets and guarantees concise responses.
# * **`stop` / `stop_sequences`**: Defines explicit delimiter strings where the LLM immediately stops generating further tokens. Useful for few-shot boundaries, Markdown blocks, or specific turn delimiters.

# %%
# Demonstrating max_output_tokens and stop sequences
llm_constrained = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash",
    temperature=0.2,
    max_output_tokens=40,
    stop=["3."]
)

response_constrained = llm_constrained.invoke("List the steps in the scientific method:\n1. Observation\n2....")
print("--- Constrained Output (Max 40 tokens or halted before '3.') ---")
print(f"2. {response_constrained.content}")

# Dynamic runtime configuration override using .bind()
print("\n--- Runtime Parameter Binding with .bind() ---")
bound_llm = llm.bind(temperature=0.0, max_output_tokens=25)
print(bound_llm.invoke("What is the exact speed of light in m/s? Be succinct.").content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# --- Constrained Output (Max 40 tokens or halted before '3.') ---
# 2. []
#
# --- Runtime Parameter Binding with .bind() ---
# []
