# %% [markdown]
# <a href="https://colab.research.google.com/github/mokenyu/hello-world-repo-honratech/blob/main/honra_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Initialization

# %%
# !pip install langchain langchain_google_genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 835.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 21.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
# ...

# %% [markdown]
# #### Using Google's Special Wrapper

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
response = llm.invoke("What is the navier-stokes equation") # Write your prompt in the quotes
response.content
# Out:
# 'The **Navier-Stokes equations** are a set of fundamental equations in fluid dynamics that describe the motion of viscous fluid substances. They are essentially an application of Newton\'s second law ($F=ma$) to a fluid element, accounting for the various forces acting on it.\n\nThey are incredibly important because they underpin our understanding and ability to predict a vast range of phenomena, from weather patterns and ocean currents to the lift on an aircraft wing, the flow of blood in arteries, and the design of pipelines.\n\n### What they describe:\n\nIn essence, the Navier-Stokes equations describe how the **velocity, pressure, temperature, and density** of a moving fluid are related and evolve over time and space.\n\n### The Equations (Simplified Form for Incompressible Flow):\n\nThere isn\'t *one* single Navier-Stokes equation, but rather a set of coupled partial differential equations. The most common and illustrative form is for **incompressible, Newtonian fluids with cons
# ...

# %% [markdown]
# #### Using the generic wrapper

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("google_genai:gemini-2.5-flash")
response = llm.invoke("niche facts about water")
response.content
# Out:
# 'Water, despite its apparent simplicity, is full of bizarre and counter-intuitive properties. Here are some niche facts about it:\n\n1.  **The Mpemba Effect:** Hot water can sometimes freeze faster than cold water under certain conditions. While observed for centuries, the exact reasons are still debated, involving factors like evaporation, dissolved gases, convection currents, and hydrogen bonding.\n\n2.  **Density Anomaly (Maximum Density at 4°C):** Unlike most substances that become denser as they cool, water reaches its maximum density at approximately 4°C (39.2°F). Below this temperature, it becomes less dense, which is why ice floats. This property is crucial for aquatic life, as lakes and oceans freeze from the top down, insulating the water below.\n\n3.  **Supercooling is Possible:** Water can remain a liquid well below its freezing point (0°C or 32°F) if it\'s very pure and undisturbed. This "supercooled" water will instantly freeze when agitated or if a nucleation site (lik
# ...
